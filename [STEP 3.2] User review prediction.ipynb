# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

from tabulate import tabulate
from scipy import stats

from flaml import AutoML
from flaml.automl.data import get_output_from_log

from dython.nominal import associations
from mrmr import mrmr_regression, mrmr_classif

from scipy.stats import gaussian_kde

import statsmodels.api as sm

sklearn.set_config(transform_output="pandas")

import seaborn as sns

# %%
visits = pd.read_csv('Modified_Data/visits.csv')

# %% [markdown]
# ## Preparing the data

# %%
id_columns = [col for col in visits.columns if '_id' in col]
print("We are dropping the following columns:", id_columns)
visits.drop(columns=id_columns, inplace=True)
# Out:
# We are dropping the following columns: ['visit_id', 'customer_id', 'transaction_id']

# %%
# drop columns 
visits.drop(columns=['start_timestamp', 'end_timestamp', 'user_first_name', 
                     'user_last_name', 'email', 'purchase_date', 'purchase_price', 
                     'release_date', 'month_year','switch_type'], inplace=True)

# %% [markdown]
# ### Null values

# %%
visits.isna().sum()
# Out:
# visit_type                  0
# visit_duration_time         0
# gender                      0
# email_domain             3787
# platform               125546
# user_review            398264
# car_model              125546
# fuel_type              125546
# price                  125546
# discount               125546
# car_age_days           125546
# purchased                   0
# average_visit_time          0
# visit_number                0
# reviewed                    0
# engaged                     0
# loyalty                     0
# dtype: int64

# %% [markdown]
# For now we don't care about those who didn't bought at least a car, so we are going to drop the nans

# %%
# drop the nans
visits.dropna(inplace=True)

# %%
y = visits['user_review']
X = visits.drop(columns=['user_review', 'reviewed'])

# %%
# get dummies
X = pd.get_dummies(X)
X.shape
# Out:
# (40308, 38)

# %% [markdown]
# ## Analyse the features

# %%
associations = associations(visits, multiprocessing=True, cmap='gnuplot', num_num_assoc='spearman')

# %%
selected_features = mrmr_classif(X=X, y=y, K=100)
print(selected_features)
# Out:
# 100%|██████████| 38/38 [00:05<00:00,  7.10it/s]
# ['platform_Dealership', 'email_domain_yahoo.com', 'price', 'average_visit_time', 'platform_Website', 'platform_Mobile App', 'car_model_Model i8', 'fuel_type_Electric', 'visit_type_testing', 'fuel_type_Diesel', 'visit_duration_time', 'car_model_1 Series', 'car_age_days', 'visit_type_car configuration', 'gender_Other', 'discount', 'car_model_Sedan', 'email_domain_outlook.com', 'car_model_Model iX', 'car_model_Model M', 'loyalty', 'car_model_3 Series', 'email_domain_hotmail.com', 'visit_type_viewing', 'car_model_Model i7', 'fuel_type_Gasoline', 'car_model_Sierra', 'gender_Female', 'car_model_Tourer', 'car_model_Model iY', 'car_model_Touring', 'visit_number', 'email_domain_gmail.com', 'car_model_Coupe', 'gender_Male', 'engaged', 'purchased', 'visit_type_purchasing']

# %% [markdown]
# ## Train

# %%
# creating the train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
automl = AutoML()
automl.fit(X_train, y_train, task="regression", time_budget=1800 , metric="mape", log_file_name="user_review.log", eval_method="cv", n_splits=5, n_jobs=-1, verbose=3)
# Out:
# [flaml.automl.logger: 12-03 09:21:50] {1728} INFO - task = regression
# [flaml.automl.logger: 12-03 09:21:50] {1739} INFO - Evaluation method: cv
# [flaml.automl.logger: 12-03 09:21:50] {1838} INFO - Minimizing error metric: mape
# [flaml.automl.logger: 12-03 09:21:50] {1955} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd']
# [flaml.automl.logger: 12-03 09:21:50] {2258} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-03 09:21:51] {2393} INFO - Estimated sufficient time budget=6011s. Estimated necessary time budget=43s.
# [flaml.automl.logger: 12-03 09:21:51] {2442} INFO -  at 0.9s,	estimator lgbm's best error=0.8045,	best estimator lgbm's best error=0.8045
# [flaml.automl.logger: 12-03 09:21:51] {2258} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-03 09:21:51] {2442} INFO -  at 1.3s,	estimator lgbm's best error=0.8045,	best estimator lgbm's best error=0.8045
# [flaml.automl.logger: 12-03 09:21:51] {2258} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 12-03 09:21:51] {2442} INFO -  at 1.7s,	estimator lgbm's best error=0.7037,	best estimator lgbm's best error=0.7037
# [flaml.automl.logger: 12-03 09:21:51] {2258} INFO - iteration 3, current learner sgd
# [flaml.automl.logger: 12-03 09:21:57] {2442} INFO -  at 7.6s,	estimator sgd's best error=0.8941,	best estimator lgbm's best error=0.7037
# [flaml.automl.logger: 12-03 09:21:57] {2258} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 12-03 09:21:58] {2442} INFO -  at 8.3s,	estimator lgbm's best error=0.5185,	best estimator lgbm's best error=0.5185
# [flaml.automl.logger: 12-03 09:21:58] {2258} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 12-03 09:21:58] {2442} INFO -  at 8.7s,	estimator lgbm's best error=0.5185,	best estimator lgbm's best error=0.5185
# [flaml.automl.logger: 12-03 09:21:58] {2258} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 12-03 09:22:00] {2442} INFO -  at 10.0s,	estimator lgbm's best error=0.4936,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:00] {2258} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:00] {2442} INFO -  at 10.5s,	estimator xgboost's best error=0.8042,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:00] {2258} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 12-03 09:22:01] {2442} INFO -  at 11.1s,	estimator lgbm's best error=0.4936,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:01] {2258} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 12-03 09:22:01] {2442} INFO -  at 11.5s,	estimator lgbm's best error=0.4936,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:01] {2258} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:02] {2442} INFO -  at 12.1s,	estimator xgboost's best error=0.8042,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:02] {2258} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:02] {2442} INFO -  at 12.6s,	estimator xgboost's best error=0.7073,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:02] {2258} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 12-03 09:22:03] {2442} INFO -  at 13.0s,	estimator extra_tree's best error=0.6674,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:03] {2258} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 12-03 09:22:03] {2442} INFO -  at 13.5s,	estimator extra_tree's best error=0.6510,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:03] {2258} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 12-03 09:22:04] {2442} INFO -  at 13.9s,	estimator rf's best error=0.6526,	best estimator lgbm's best error=0.4936
# [flaml.automl.logger: 12-03 09:22:04] {2258} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 12-03 09:22:04] {2442} INFO -  at 14.5s,	estimator rf's best error=0.4561,	best estimator rf's best error=0.4561
# [flaml.automl.logger: 12-03 09:22:04] {2258} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 12-03 09:22:05] {2442} INFO -  at 15.0s,	estimator rf's best error=0.4561,	best estimator rf's best error=0.4561
# [flaml.automl.logger: 12-03 09:22:05] {2258} INFO - iteration 17, current learner rf
# [flaml.automl.logger: 12-03 09:22:06] {2442} INFO -  at 16.1s,	estimator rf's best error=0.4098,	best estimator rf's best error=0.4098
# [flaml.automl.logger: 12-03 09:22:06] {2258} INFO - iteration 18, current learner sgd
# [flaml.automl.logger: 12-03 09:22:08] {2442} INFO -  at 18.8s,	estimator sgd's best error=0.8941,	best estimator rf's best error=0.4098
# [flaml.automl.logger: 12-03 09:22:08] {2258} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 12-03 09:22:10] {2442} INFO -  at 20.1s,	estimator lgbm's best error=0.4846,	best estimator rf's best error=0.4098
# [flaml.automl.logger: 12-03 09:22:10] {2258} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:10] {2442} INFO -  at 20.4s,	estimator xgboost's best error=0.5561,	best estimator rf's best error=0.4098
# [flaml.automl.logger: 12-03 09:22:10] {2258} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:10] {2442} INFO -  at 20.8s,	estimator xgboost's best error=0.5561,	best estimator rf's best error=0.4098
# [flaml.automl.logger: 12-03 09:22:10] {2258} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:11] {2442} INFO -  at 21.2s,	estimator xgboost's best error=0.5561,	best estimator rf's best error=0.4098
# [flaml.automl.logger: 12-03 09:22:11] {2258} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 12-03 09:22:12] {2442} INFO -  at 22.1s,	estimator rf's best error=0.3345,	best estimator rf's best error=0.3345
# [flaml.automl.logger: 12-03 09:22:12] {2258} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 12-03 09:22:13] {2442} INFO -  at 23.2s,	estimator rf's best error=0.3345,	best estimator rf's best error=0.3345
# [flaml.automl.logger: 12-03 09:22:13] {2258} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:13] {2442} INFO -  at 23.7s,	estimator xgboost's best error=0.4975,	best estimator rf's best error=0.3345
# [flaml.automl.logger: 12-03 09:22:13] {2258} INFO - iteration 26, current learner sgd
# [flaml.automl.logger: 12-03 09:22:15] {2442} INFO -  at 25.4s,	estimator sgd's best error=0.8404,	best estimator rf's best error=0.3345
# [flaml.automl.logger: 12-03 09:22:15] {2258} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 12-03 09:22:16] {2442} INFO -  at 26.6s,	estimator rf's best error=0.2659,	best estimator rf's best error=0.2659
# [flaml.automl.logger: 12-03 09:22:16] {2258} INFO - iteration 28, current learner rf
# [flaml.automl.logger: 12-03 09:22:17] {2442} INFO -  at 27.5s,	estimator rf's best error=0.2659,	best estimator rf's best error=0.2659
# [flaml.automl.logger: 12-03 09:22:17] {2258} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:18] {2442} INFO -  at 28.3s,	estimator xgboost's best error=0.4757,	best estimator rf's best error=0.2659
# [flaml.automl.logger: 12-03 09:22:18] {2258} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:18] {2442} INFO -  at 28.9s,	estimator xgboost's best error=0.4757,	best estimator rf's best error=0.2659
# [flaml.automl.logger: 12-03 09:22:18] {2258} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 12-03 09:22:20] {2442} INFO -  at 30.8s,	estimator rf's best error=0.2602,	best estimator rf's best error=0.2602
# [flaml.automl.logger: 12-03 09:22:20] {2258} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 12-03 09:22:22] {2442} INFO -  at 31.9s,	estimator rf's best error=0.2602,	best estimator rf's best error=0.2602
# [flaml.automl.logger: 12-03 09:22:22] {2258} INFO - iteration 33, current learner rf
# [flaml.automl.logger: 12-03 09:22:23] {2442} INFO -  at 33.3s,	estimator rf's best error=0.2150,	best estimator rf's best error=0.2150
# [flaml.automl.logger: 12-03 09:22:23] {2258} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:24] {2442} INFO -  at 34.1s,	estimator xgboost's best error=0.3903,	best estimator rf's best error=0.2150
# [flaml.automl.logger: 12-03 09:22:24] {2258} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 12-03 09:22:25] {2442} INFO -  at 34.9s,	estimator rf's best error=0.2150,	best estimator rf's best error=0.2150
# [flaml.automl.logger: 12-03 09:22:25] {2258} INFO - iteration 36, current learner rf
# [flaml.automl.logger: 12-03 09:22:27] {2442} INFO -  at 37.6s,	estimator rf's best error=0.1673,	best estimator rf's best error=0.1673
# [flaml.automl.logger: 12-03 09:22:27] {2258} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 12-03 09:22:28] {2442} INFO -  at 38.3s,	estimator extra_tree's best error=0.6510,	best estimator rf's best error=0.1673
# [flaml.automl.logger: 12-03 09:22:28] {2258} INFO - iteration 38, current learner rf
# [flaml.automl.logger: 12-03 09:22:29] {2442} INFO -  at 39.9s,	estimator rf's best error=0.1673,	best estimator rf's best error=0.1673
# [flaml.automl.logger: 12-03 09:22:29] {2258} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:30] {2442} INFO -  at 40.6s,	estimator xgboost's best error=0.3903,	best estimator rf's best error=0.1673
# [flaml.automl.logger: 12-03 09:22:30] {2258} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 12-03 09:22:34] {2442} INFO -  at 44.7s,	estimator rf's best error=0.1499,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:22:34] {2258} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:35] {2442} INFO -  at 45.2s,	estimator xgboost's best error=0.3903,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:22:35] {2258} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 12-03 09:22:36] {2442} INFO -  at 46.6s,	estimator xgboost's best error=0.3891,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:22:36] {2258} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 12-03 09:22:37] {2442} INFO -  at 47.1s,	estimator lgbm's best error=0.4846,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:22:37] {2258} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 12-03 09:22:39] {2442} INFO -  at 49.2s,	estimator rf's best error=0.1499,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:22:39] {2258} INFO - iteration 45, current learner sgd
# [flaml.automl.logger: 12-03 09:23:15] {2442} INFO -  at 85.1s,	estimator sgd's best error=0.8404,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:23:15] {2258} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 12-03 09:23:23] {2442} INFO -  at 93.6s,	estimator rf's best error=0.1499,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:23:23] {2258} INFO - iteration 47, current learner rf
# [flaml.automl.logger: 12-03 09:23:30] {2442} INFO -  at 100.2s,	estimator rf's best error=0.1499,	best estimator rf's best error=0.1499
# [flaml.automl.logger: 12-03 09:23:30] {2258} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 12-03 09:23:32] {2442} INFO -  at 102.5s,	estimator rf's best error=0.1418,	best estimator rf's best error=0.1418
# [flaml.automl.logger: 12-03 09:23:32] {2258} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 12-03 09:23:38] {2442} INFO -  at 108.4s,	estimator rf's best error=0.1418,	best estimator rf's best error=0.1418
# [flaml.automl.logger: 12-03 09:23:38] {2258} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 12-03 09:23:39] {2442} INFO -  at 109.8s,	estimator rf's best error=0.1418,	best estimator rf's best error=0.1418
# [flaml.automl.logger: 12-03 09:23:39] {2258} INFO - iteration 51, current learner extra_tree
# [flaml.automl.logger: 12-03 09:23:40] {2442} INFO -  at 110.4s,	estimator extra_tree's best error=0.5815,	best estimator rf's best error=0.1418
# [flaml.automl.logger: 12-03 09:23:40] {2258} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 12-03 09:23:41] {2442} INFO -  at 111.9s,	estimator rf's best error=0.1418,	best estimator rf's best error=0.1418
# [flaml.automl.logger: 12-03 09:23:41] {2258} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 12-03 09:23:45] {2442} INFO -  at 115.8s,	estimator rf's best error=0.1418,	best estimator rf's best error=0.1418
# [flaml.automl.logger: 12-03 09:23:45] {2258} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 12-03 09:23:48] {2442} INFO -  at 118.6s,	estimator rf's best error=0.1298,	best estimator rf's best error=0.1298
# [flaml.automl.logger: 12-03 09:23:48] {2258} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 12-03 09:23:52] {2442} INFO -  at 122.6s,	estimator lgbm's best error=0.3434,	best estimator rf's best error=0.1298
# [flaml.automl.logger: 12-03 09:23:52] {2258} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 12-03 09:23:55] {2442} INFO -  at 125.0s,	estimator rf's best error=0.1298,	best estimator rf's best error=0.1298
# [flaml.automl.logger: 12-03 09:23:55] {2258} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 12-03 09:24:00] {2442} INFO -  at 130.8s,	estimator lgbm's best error=0.1990,	best estimator rf's best error=0.1298
# [flaml.automl.logger: 12-03 09:24:00] {2258} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 12-03 09:24:04] {2442} INFO -  at 134.8s,	estimator lgbm's best error=0.1990,	best estimator rf's best error=0.1298
# [flaml.automl.logger: 12-03 09:24:04] {2258} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 12-03 09:24:10] {2442} INFO -  at 140.7s,	estimator rf's best error=0.1268,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:10] {2258} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 12-03 09:24:18] {2442} INFO -  at 148.7s,	estimator lgbm's best error=0.1990,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:18] {2258} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 12-03 09:24:21] {2442} INFO -  at 150.9s,	estimator rf's best error=0.1268,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:21] {2258} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 12-03 09:24:26] {2442} INFO -  at 155.9s,	estimator lgbm's best error=0.1773,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:26] {2258} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 12-03 09:24:29] {2442} INFO -  at 159.6s,	estimator rf's best error=0.1268,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:29] {2258} INFO - iteration 64, current learner extra_tree
# [flaml.automl.logger: 12-03 09:24:30] {2442} INFO -  at 160.2s,	estimator extra_tree's best error=0.5205,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:30] {2258} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 12-03 09:24:34] {2442} INFO -  at 164.0s,	estimator rf's best error=0.1268,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:34] {2258} INFO - iteration 66, current learner rf
# [flaml.automl.logger: 12-03 09:24:36] {2442} INFO -  at 166.7s,	estimator rf's best error=0.1268,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:36] {2258} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 12-03 09:24:37] {2442} INFO -  at 167.4s,	estimator extra_tree's best error=0.5205,	best estimator rf's best error=0.1268
# [flaml.automl.logger: 12-03 09:24:37] {2258} INFO - iteration 68, current learner rf
# [flaml.automl.logger: 12-03 09:24:45] {2442} INFO -  at 175.8s,	estimator rf's best error=0.1254,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:24:45] {2258} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 12-03 09:24:56] {2442} INFO -  at 186.1s,	estimator lgbm's best error=0.1773,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:24:56] {2258} INFO - iteration 70, current learner extra_tree
# [flaml.automl.logger: 12-03 09:24:56] {2442} INFO -  at 186.8s,	estimator extra_tree's best error=0.4517,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:24:56] {2258} INFO - iteration 71, current learner extra_tree
# [flaml.automl.logger: 12-03 09:24:57] {2442} INFO -  at 187.8s,	estimator extra_tree's best error=0.4517,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:24:57] {2258} INFO - iteration 72, current learner rf
# [flaml.automl.logger: 12-03 09:25:05] {2442} INFO -  at 195.7s,	estimator rf's best error=0.1254,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:25:05] {2258} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 12-03 09:25:07] {2442} INFO -  at 197.2s,	estimator extra_tree's best error=0.4247,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:25:07] {2258} INFO - iteration 74, current learner rf
# [flaml.automl.logger: 12-03 09:25:12] {2442} INFO -  at 202.3s,	estimator rf's best error=0.1254,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:25:12] {2258} INFO - iteration 75, current learner extra_tree
# [flaml.automl.logger: 12-03 09:25:13] {2442} INFO -  at 203.6s,	estimator extra_tree's best error=0.4247,	best estimator rf's best error=0.1254
# [flaml.automl.logger: 12-03 09:25:13] {2258} INFO - iteration 76, current learner rf
# [flaml.automl.logger: 12-03 09:25:28] {2442} INFO -  at 218.2s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:25:28] {2258} INFO - iteration 77, current learner rf
# [flaml.automl.logger: 12-03 09:25:33] {2442} INFO -  at 223.8s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:25:33] {2258} INFO - iteration 78, current learner extra_tree
# [flaml.automl.logger: 12-03 09:25:35] {2442} INFO -  at 225.2s,	estimator extra_tree's best error=0.3251,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:25:35] {2258} INFO - iteration 79, current learner extra_tree
# [flaml.automl.logger: 12-03 09:25:36] {2442} INFO -  at 226.1s,	estimator extra_tree's best error=0.3251,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:25:36] {2258} INFO - iteration 80, current learner rf
# [flaml.automl.logger: 12-03 09:25:42] {2442} INFO -  at 232.3s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:25:42] {2258} INFO - iteration 81, current learner extra_tree
# [flaml.automl.logger: 12-03 09:25:44] {2442} INFO -  at 234.4s,	estimator extra_tree's best error=0.2698,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:25:44] {2258} INFO - iteration 82, current learner rf
# [flaml.automl.logger: 12-03 09:26:13] {2442} INFO -  at 263.8s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:13] {2258} INFO - iteration 83, current learner extra_tree
# [flaml.automl.logger: 12-03 09:26:15] {2442} INFO -  at 265.1s,	estimator extra_tree's best error=0.2698,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:15] {2258} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 12-03 09:26:19] {2442} INFO -  at 269.1s,	estimator extra_tree's best error=0.2229,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:19] {2258} INFO - iteration 85, current learner extra_tree
# [flaml.automl.logger: 12-03 09:26:20] {2442} INFO -  at 270.9s,	estimator extra_tree's best error=0.2189,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:21] {2258} INFO - iteration 86, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:21] {2442} INFO -  at 271.5s,	estimator xgb_limitdepth's best error=0.4630,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:21] {2258} INFO - iteration 87, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:22] {2442} INFO -  at 272.0s,	estimator xgb_limitdepth's best error=0.4630,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:22] {2258} INFO - iteration 88, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:22] {2442} INFO -  at 272.6s,	estimator xgb_limitdepth's best error=0.3780,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:22] {2258} INFO - iteration 89, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:23] {2442} INFO -  at 273.2s,	estimator xgb_limitdepth's best error=0.3780,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:23] {2258} INFO - iteration 90, current learner extra_tree
# [flaml.automl.logger: 12-03 09:26:26] {2442} INFO -  at 276.2s,	estimator extra_tree's best error=0.2189,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:26] {2258} INFO - iteration 91, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:26] {2442} INFO -  at 276.7s,	estimator xgb_limitdepth's best error=0.3780,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:26] {2258} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:27] {2442} INFO -  at 277.1s,	estimator xgb_limitdepth's best error=0.3780,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:27] {2258} INFO - iteration 93, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:28] {2442} INFO -  at 278.2s,	estimator xgb_limitdepth's best error=0.2783,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:28] {2258} INFO - iteration 94, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:30] {2442} INFO -  at 280.0s,	estimator xgb_limitdepth's best error=0.2583,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:30] {2258} INFO - iteration 95, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:31] {2442} INFO -  at 281.3s,	estimator xgb_limitdepth's best error=0.2583,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:31] {2258} INFO - iteration 96, current learner lgbm
# [flaml.automl.logger: 12-03 09:26:36] {2442} INFO -  at 286.7s,	estimator lgbm's best error=0.1773,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:36] {2258} INFO - iteration 97, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:26:39] {2442} INFO -  at 289.7s,	estimator xgb_limitdepth's best error=0.2335,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:26:39] {2258} INFO - iteration 98, current learner rf
# [flaml.automl.logger: 12-03 09:27:09] {2442} INFO -  at 319.0s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:27:09] {2258} INFO - iteration 99, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:27:11] {2442} INFO -  at 321.7s,	estimator xgb_limitdepth's best error=0.2335,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:27:11] {2258} INFO - iteration 100, current learner rf
# [flaml.automl.logger: 12-03 09:27:19] {2442} INFO -  at 329.6s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:27:19] {2258} INFO - iteration 101, current learner rf
# [flaml.automl.logger: 12-03 09:27:44] {2442} INFO -  at 354.7s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:27:44] {2258} INFO - iteration 102, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:27:46] {2442} INFO -  at 356.2s,	estimator xgb_limitdepth's best error=0.2335,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:27:46] {2258} INFO - iteration 103, current learner extra_tree
# [flaml.automl.logger: 12-03 09:27:49] {2442} INFO -  at 359.1s,	estimator extra_tree's best error=0.2189,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:27:49] {2258} INFO - iteration 104, current learner lgbm
# [flaml.automl.logger: 12-03 09:28:05] {2442} INFO -  at 375.3s,	estimator lgbm's best error=0.1600,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:28:05] {2258} INFO - iteration 105, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:28:10] {2442} INFO -  at 380.4s,	estimator xgb_limitdepth's best error=0.2245,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:28:10] {2258} INFO - iteration 106, current learner rf
# [flaml.automl.logger: 12-03 09:28:17] {2442} INFO -  at 387.5s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:28:17] {2258} INFO - iteration 107, current learner rf
# [flaml.automl.logger: 12-03 09:28:27] {2442} INFO -  at 397.1s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:28:27] {2258} INFO - iteration 108, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:28:28] {2442} INFO -  at 398.6s,	estimator xgb_limitdepth's best error=0.2245,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:28:28] {2258} INFO - iteration 109, current learner rf
# [flaml.automl.logger: 12-03 09:28:51] {2442} INFO -  at 421.7s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:28:51] {2258} INFO - iteration 110, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:29:05] {2442} INFO -  at 435.0s,	estimator xgb_limitdepth's best error=0.2245,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:05] {2258} INFO - iteration 111, current learner rf
# [flaml.automl.logger: 12-03 09:29:14] {2442} INFO -  at 444.6s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:14] {2258} INFO - iteration 112, current learner lgbm
# [flaml.automl.logger: 12-03 09:29:20] {2442} INFO -  at 450.6s,	estimator lgbm's best error=0.1600,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:20] {2258} INFO - iteration 113, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:29:22] {2442} INFO -  at 452.9s,	estimator xgb_limitdepth's best error=0.2245,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:22] {2258} INFO - iteration 114, current learner xgboost
# [flaml.automl.logger: 12-03 09:29:23] {2442} INFO -  at 453.7s,	estimator xgboost's best error=0.3676,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:23] {2258} INFO - iteration 115, current learner sgd
# [flaml.automl.logger: 12-03 09:29:27] {2442} INFO -  at 457.1s,	estimator sgd's best error=0.8189,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:27] {2258} INFO - iteration 116, current learner rf
# [flaml.automl.logger: 12-03 09:29:45] {2442} INFO -  at 475.7s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:29:45] {2258} INFO - iteration 117, current learner rf
# [flaml.automl.logger: 12-03 09:30:13] {2442} INFO -  at 503.2s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:13] {2258} INFO - iteration 118, current learner extra_tree
# [flaml.automl.logger: 12-03 09:30:14] {2442} INFO -  at 504.3s,	estimator extra_tree's best error=0.1983,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:14] {2258} INFO - iteration 119, current learner xgboost
# [flaml.automl.logger: 12-03 09:30:16] {2442} INFO -  at 505.9s,	estimator xgboost's best error=0.3676,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:16] {2258} INFO - iteration 120, current learner lgbm
# [flaml.automl.logger: 12-03 09:30:19] {2442} INFO -  at 509.0s,	estimator lgbm's best error=0.1453,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:19] {2258} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 12-03 09:30:21] {2442} INFO -  at 511.0s,	estimator extra_tree's best error=0.1983,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:21] {2258} INFO - iteration 122, current learner xgboost
# [flaml.automl.logger: 12-03 09:30:21] {2442} INFO -  at 511.7s,	estimator xgboost's best error=0.3676,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:21] {2258} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 12-03 09:30:23] {2442} INFO -  at 513.1s,	estimator extra_tree's best error=0.1983,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:23] {2258} INFO - iteration 124, current learner xgboost
# [flaml.automl.logger: 12-03 09:30:26] {2442} INFO -  at 516.4s,	estimator xgboost's best error=0.3024,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:26] {2258} INFO - iteration 125, current learner lgbm
# [flaml.automl.logger: 12-03 09:30:35] {2442} INFO -  at 525.9s,	estimator lgbm's best error=0.1453,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:35] {2258} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 12-03 09:30:39] {2442} INFO -  at 529.8s,	estimator lgbm's best error=0.1453,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:39] {2258} INFO - iteration 127, current learner lgbm
# [flaml.automl.logger: 12-03 09:30:42] {2442} INFO -  at 532.0s,	estimator lgbm's best error=0.1453,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:42] {2258} INFO - iteration 128, current learner lgbm
# [flaml.automl.logger: 12-03 09:30:44] {2442} INFO -  at 534.4s,	estimator lgbm's best error=0.1453,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:44] {2258} INFO - iteration 129, current learner rf
# [flaml.automl.logger: 12-03 09:30:53] {2442} INFO -  at 543.6s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:53] {2258} INFO - iteration 130, current learner extra_tree
# [flaml.automl.logger: 12-03 09:30:55] {2442} INFO -  at 545.4s,	estimator extra_tree's best error=0.1880,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:55] {2258} INFO - iteration 131, current learner xgboost
# [flaml.automl.logger: 12-03 09:30:56] {2442} INFO -  at 545.9s,	estimator xgboost's best error=0.3024,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:30:56] {2258} INFO - iteration 132, current learner xgboost
# [flaml.automl.logger: 12-03 09:31:00] {2442} INFO -  at 550.4s,	estimator xgboost's best error=0.2677,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:31:00] {2258} INFO - iteration 133, current learner extra_tree
# [flaml.automl.logger: 12-03 09:31:02] {2442} INFO -  at 552.2s,	estimator extra_tree's best error=0.1880,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:31:02] {2258} INFO - iteration 134, current learner lgbm
# [flaml.automl.logger: 12-03 09:31:07] {2442} INFO -  at 557.8s,	estimator lgbm's best error=0.1453,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:31:07] {2258} INFO - iteration 135, current learner rf
# [flaml.automl.logger: 12-03 09:31:16] {2442} INFO -  at 566.2s,	estimator rf's best error=0.1235,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:31:16] {2258} INFO - iteration 136, current learner xgboost
# [flaml.automl.logger: 12-03 09:31:17] {2442} INFO -  at 567.7s,	estimator xgboost's best error=0.2677,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:31:17] {2258} INFO - iteration 137, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:31:25] {2442} INFO -  at 575.8s,	estimator xgb_limitdepth's best error=0.2245,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:31:25] {2258} INFO - iteration 138, current learner xgboost
# [flaml.automl.logger: 12-03 09:32:22] {2442} INFO -  at 632.1s,	estimator xgboost's best error=0.2180,	best estimator rf's best error=0.1235
# [flaml.automl.logger: 12-03 09:32:22] {2258} INFO - iteration 139, current learner lgbm
# [flaml.automl.logger: 12-03 09:32:45] {2442} INFO -  at 655.0s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:32:45] {2258} INFO - iteration 140, current learner extra_tree
# [flaml.automl.logger: 12-03 09:32:46] {2442} INFO -  at 656.7s,	estimator extra_tree's best error=0.1805,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:32:46] {2258} INFO - iteration 141, current learner lgbm
# [flaml.automl.logger: 12-03 09:32:50] {2442} INFO -  at 660.7s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:32:50] {2258} INFO - iteration 142, current learner extra_tree
# [flaml.automl.logger: 12-03 09:32:52] {2442} INFO -  at 661.9s,	estimator extra_tree's best error=0.1805,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:32:52] {2258} INFO - iteration 143, current learner lgbm
# [flaml.automl.logger: 12-03 09:33:16] {2442} INFO -  at 685.9s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:33:16] {2258} INFO - iteration 144, current learner extra_tree
# [flaml.automl.logger: 12-03 09:33:18] {2442} INFO -  at 688.1s,	estimator extra_tree's best error=0.1707,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:33:18] {2258} INFO - iteration 145, current learner extra_tree
# [flaml.automl.logger: 12-03 09:33:19] {2442} INFO -  at 689.6s,	estimator extra_tree's best error=0.1707,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:33:19] {2258} INFO - iteration 146, current learner xgboost
# [flaml.automl.logger: 12-03 09:33:41] {2442} INFO -  at 711.6s,	estimator xgboost's best error=0.2180,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:33:41] {2258} INFO - iteration 147, current learner lgbm
# [flaml.automl.logger: 12-03 09:33:44] {2442} INFO -  at 714.0s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:33:44] {2258} INFO - iteration 148, current learner lgbm
# [flaml.automl.logger: 12-03 09:33:45] {2442} INFO -  at 715.7s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:33:45] {2258} INFO - iteration 149, current learner lgbm
# [flaml.automl.logger: 12-03 09:34:12] {2442} INFO -  at 742.2s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:34:12] {2258} INFO - iteration 150, current learner lgbm
# [flaml.automl.logger: 12-03 09:34:18] {2442} INFO -  at 748.0s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:34:18] {2258} INFO - iteration 151, current learner lgbm
# [flaml.automl.logger: 12-03 09:34:26] {2442} INFO -  at 756.0s,	estimator lgbm's best error=0.0964,	best estimator lgbm's best error=0.0964
# [flaml.automl.logger: 12-03 09:34:26] {2258} INFO - iteration 152, current learner lgbm
# [flaml.automl.logger: 12-03 09:34:35] {2442} INFO -  at 765.0s,	estimator lgbm's best error=0.0943,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:34:35] {2258} INFO - iteration 153, current learner extra_tree
# [flaml.automl.logger: 12-03 09:34:36] {2442} INFO -  at 766.5s,	estimator extra_tree's best error=0.1707,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:34:36] {2258} INFO - iteration 154, current learner xgboost
# [flaml.automl.logger: 12-03 09:36:54] {2442} INFO -  at 904.4s,	estimator xgboost's best error=0.2180,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:36:54] {2258} INFO - iteration 155, current learner lgbm
# [flaml.automl.logger: 12-03 09:37:14] {2442} INFO -  at 923.9s,	estimator lgbm's best error=0.0943,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:37:14] {2258} INFO - iteration 156, current learner lgbm
# [flaml.automl.logger: 12-03 09:38:57] {2442} INFO -  at 1027.4s,	estimator lgbm's best error=0.0943,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:38:57] {2258} INFO - iteration 157, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:39:00] {2442} INFO -  at 1030.4s,	estimator xgb_limitdepth's best error=0.2245,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:39:00] {2258} INFO - iteration 158, current learner extra_tree
# [flaml.automl.logger: 12-03 09:39:03] {2442} INFO -  at 1033.2s,	estimator extra_tree's best error=0.1707,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:39:03] {2258} INFO - iteration 159, current learner lgbm
# [flaml.automl.logger: 12-03 09:39:09] {2442} INFO -  at 1039.5s,	estimator lgbm's best error=0.0943,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:39:09] {2258} INFO - iteration 160, current learner lgbm
# [flaml.automl.logger: 12-03 09:39:49] {2442} INFO -  at 1079.1s,	estimator lgbm's best error=0.0943,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:39:49] {2258} INFO - iteration 161, current learner extra_tree
# [flaml.automl.logger: 12-03 09:39:50] {2442} INFO -  at 1080.3s,	estimator extra_tree's best error=0.1707,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:39:50] {2258} INFO - iteration 162, current learner lgbm
# [flaml.automl.logger: 12-03 09:40:00] {2442} INFO -  at 1090.8s,	estimator lgbm's best error=0.0943,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:40:00] {2258} INFO - iteration 163, current learner extra_tree
# [flaml.automl.logger: 12-03 09:40:04] {2442} INFO -  at 1094.6s,	estimator extra_tree's best error=0.1620,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:40:04] {2258} INFO - iteration 164, current learner xgb_limitdepth
# [flaml.automl.logger: 12-03 09:40:21] {2442} INFO -  at 1111.3s,	estimator xgb_limitdepth's best error=0.2212,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:40:21] {2258} INFO - iteration 165, current learner extra_tree
# [flaml.automl.logger: 12-03 09:40:25] {2442} INFO -  at 1115.7s,	estimator extra_tree's best error=0.1620,	best estimator lgbm's best error=0.0943
# [flaml.automl.logger: 12-03 09:40:25] {2258} INFO - iteration 166, current learner lgbm

# %%
time_history, best_valid_loss_history, valid_loss_history, config_history, metric_history = get_output_from_log(filename="user_review.log", time_budget=7200)

plt.title("Learning Curve")
plt.xlabel("Time (s)")
plt.ylabel("Validation Accuracy")
plt.step(time_history, 1 - np.array(best_valid_loss_history), where="post")
plt.show()


# Find the index of the best validation loss
best_index = np.argmin(best_valid_loss_history)

# Get the best configuration from the config history
best_config = config_history[best_index]

learner_name = best_config["Current Learner"]
hyperparameters = best_config["Current Hyper-parameters"]

# print the best configuration as a dictionary
print("Best Configuration based on the best validation loss:")
print(best_config["Current Learner"])
print(best_config["Current Hyper-parameters"])
# Out:
# Best Configuration based on the best validation loss:
# lgbm
# {'n_estimators': 35, 'num_leaves': 21061, 'min_child_samples': 2, 'learning_rate': 0.31074516453133305, 'log_max_bin': 9, 'colsample_bytree': 0.755171718871668, 'reg_alpha': 0.02499909814687708, 'reg_lambda': 0.0009765625}

# %%
try:
    plt.barh(automl.model.estimator.feature_name_, automl.model.estimator.feature_importances_)
except Exception as e:
    print(e)
    pass
# Out:
# 'NoneType' object has no attribute 'estimator'

# %%
# get the most useful features
print(tabulate(sorted(zip(automl.model.estimator.feature_importances_, X.columns), reverse=True)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 # get the most useful features
# ----> 2 print(tabulate(sorted(zip(automl.model.estimator.feature_importances_, X.columns), reverse=True)))
#
# AttributeError: 'NoneType' object has no attribute 'estimator'

# %% [markdown]
# ## Results

# %%
y_pred = automl.predict(X_test)

# %%
residuals = y_test - y_pred

mae = mean_absolute_error(y_test, y_pred)
nmae=((np.nansum(abs(residuals)))/(np.nansum(abs(np.nanmean(y_test)-(y_test)))))
mape = np.nanmean(abs(residuals / y_test)) * 100
rmse = mean_squared_error(y_test, y_pred, squared=False)
#nrmse = rmse/(y_test.mean())
nrmse = rmse/(y_test.max() - y_test.min())
rsq = r2_score(y_test, y_pred)
rho, __ = stats.spearmanr(y_test, y_pred)

metrics_dict = {'Mean Absolute Error': float(mae),
                'Normalized Mean Absolute Error': float(nmae),
                'Mean Absolute Percentage Error': float(mape),
                'Root Mean Squared Error': float(rmse),
                'Normalized Root Mean Squared Error': float(nrmse),
                'R2 score': float(rsq),
                'Spearman correlation (rho)': float(rho)}

print(tabulate(metrics_dict.items(), headers=['Metric', 'Value'], tablefmt='pretty'))
# Out:
# +------------------------------------+---------------------+
# |               Metric               |        Value        |
# +------------------------------------+---------------------+
# |        Mean Absolute Error         | 0.11497100043985253 |
# |   Normalized Mean Absolute Error   | 0.05100951947541201 |
# |   Mean Absolute Percentage Error   |  2.82238969165268   |
# |      Root Mean Squared Error       | 0.41472064437801043 |
# | Normalized Root Mean Squared Error | 0.04608007159755671 |
# |              R2 score              | 0.9771829488845947  |
# |     Spearman correlation (rho)     | 0.9782751227604024  |
# +------------------------------------+---------------------+

# %%
density = gaussian_kde(np.stack([y_pred, y_test]))(np.stack([y_pred, y_test]))

# %%
# un grafico per i residui che è composto da uno scatterplot sovrapposto ad un hexbin plot
def hexbin_scatter_plot(x_axis_data, y_axis_data, x_label_name, y_label_name, title_name, hexbin_color_palette, scatter_color, scatter_alpha,point_size=1, figsize=(7, 7)):
    plt.figure(figsize=figsize)
    plt.hexbin(x_axis_data, y_axis_data, gridsize=50, cmap=hexbin_color_palette)
    plt.scatter(x_axis_data, y_axis_data, color=scatter_color, alpha=scatter_alpha, s=point_size)
    plt.xlabel(x_label_name)
    plt.ylabel(y_label_name)
    plt.title(title_name)
    plt.show()

# li grafico uno accanto all'altro
plt.figure(figsize=(8, 8))
plt.scatter(y_pred, y_test, s=5, alpha=0.3, linewidths=0.5, c=density, cmap="gnuplot")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Predicted vs Actual")

residuals =  y_test - y_pred
#hexbin_scatter_plot(y_pred, y_test, "Predicted", "Actual", "Actual vs Predicted", "gnuplot", "white", scatter_alpha=0, point_size=0.3)

# %%
residuals = y_test - y_pred
sdev_resid = np.std(residuals)
standardized_residuals = residuals / sdev_resid

# %%
# QQ Plot
fig, ax = plt.subplots(figsize=(10, 7))
pp = sm.ProbPlot(standardized_residuals, fit=True)
pp.qqplot(marker='o', ms = 4, color = 'tab:blue', line='45', ax=ax)
fig.suptitle('Residual QQ Plot', fontsize=12)
# Out:
# Text(0.5, 0.98, 'Residual QQ Plot')

# %%
for feature in X_test.columns:     
    fig = plt.figure(figsize=[10, 7])

    # unique values of the feature
    unique_values = X_test[feature].unique()
    
    if pd.api.types.is_numeric_dtype(X_test[feature]) and len(unique_values) > 5:
        ax = fig.add_subplot(111)
        ax.scatter(X_test[feature], standardized_residuals)
        ax.axhline(y=0, color='black', linestyle=':')
        ax.axhline(y=3, color='red', linestyle='--')
        ax.axhline(y=-3, color='red', linestyle='--')

    elif pd.api.types.is_string_dtype(X_test[feature]) or len(unique_values) <= 5:
        # if numeric convert to string
        if pd.api.types.is_numeric_dtype(X_test[feature]):
            X_test[feature] = X_test[feature].astype(str)
        ax = sns.boxplot(x=X_test[feature], y=standardized_residuals, notch=True)
        #ruoto le etichette di 45 gradi
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
        ax.axhline(y=0, color='black', linestyle=':')
        ax.axhline(y=3, color='red', linestyle='--')
        ax.axhline(y=-3, color='red', linestyle='--')

    ax.set_xlabel(f"{feature}".lower())
    ax.set_ylabel("Standardized Residual")
    ax.set_title(f"'{feature}' vs Stand. Residual", fontsize=14)
